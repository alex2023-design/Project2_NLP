# %%
# %%capture
# !pip install unsloth
# !pip install transformers==4.56.2
# !pip install --no-deps trl==0.22.2
# !pip install jiwer
# !pip install einops addict easydict sentencepiece protobuf datasets huggingface_hub

# %%
from huggingface_hub import snapshot_download

snapshot_download(
    "unsloth/DeepSeek-OCR",
    local_dir="deepseek_ocr",
    local_dir_use_symlinks=False
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# assets/show2.jpg:   0%|          | 0.00/216k [00:00<?, ?B/s]
# assets/fig1.png:   0%|          | 0.00/396k [00:00<?, ?B/s]
# README-checkpoint.md: 0.00B [00:00, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# assets/show3.jpg:   0%|          | 0.00/247k [00:00<?, ?B/s]
# assets/show1.jpg:   0%|          | 0.00/117k [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# assets/show4.jpg:   0%|          | 0.00/269k [00:00<?, ?B/s]
# configuration_deepseek_v2.py: 0.00B [00:00, ?B/s]
# conversation.py: 0.00B [00:00, ?B/s]
# deepencoder.py: 0.00B [00:00, ?B/s]
# model-00001-of-000001.safetensors:   0%|          | 0.00/6.67G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# modeling_deepseekocr.py: 0.00B [00:00, ?B/s]
# modeling_deepseekv2.py: 0.00B [00:00, ?B/s]
# processor_config.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# '/kaggle/working/deepseek_ocr'

# %%
from unsloth import FastVisionModel
from transformers import AutoModel
import torch, os, sys

sys.path.append("/kaggle/working/deepseek_ocr")
os.environ["UNSLOTH_WARN_UNINITIALIZED"] = "0"

model, tokenizer = FastVisionModel.from_pretrained(
    "./deepseek_ocr",
    load_in_4bit=True,
    auto_model=AutoModel,
    trust_remote_code=True,
    unsloth_force_compile=True,
    use_gradient_checkpointing="unsloth",
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2026-01-04 16:18:30.326203: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767543510.519049      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767543510.570388      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767543511.012654      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767543511.012691      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767543511.012694      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767543511.012696      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.1.1: Fast Deepseekocr patching. Transformers: 4.56.2.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# Some weights of DeepseekOCRForCausalLM were not initialized from the model checkpoint at ./deepseek_ocr and are newly initialized: ['model.vision_model.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = FastVisionModel.get_peft_model(
    model,
    target_modules=[
        "q_proj","k_proj","v_proj","o_proj",
        "gate_proj","up_proj","down_proj",
    ],
    r=16,
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    random_state=3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %%
from datasets import Dataset
from PIL import Image
import json, os

ROOT = "/kaggle/input/uit-hwdb-line/UIT_HWDB_line/train_data"

data = []

for folder in os.listdir(ROOT):
    folder_path = os.path.join(ROOT, folder)
    if not os.path.isdir(folder_path):
        continue

    label_path = os.path.join(folder_path, "label.json")
    if not os.path.exists(label_path):
        continue

    with open(label_path, "r", encoding="utf-8") as f:
        labels = json.load(f)

    for img_name, text in labels.items():
        img_path = os.path.join(folder_path, img_name)
        if os.path.exists(img_path):
            data.append({
                "image": Image.open(img_path).convert("RGB"),
                "text": text
            })

dataset = Dataset.from_list(data[:1000])  # giới hạn để test
print("Samples:", len(dataset))
# Out:
# Samples: 1000

# %%
instruction = "\nFree OCR. "

def convert_to_conversation(sample):
    return {
        "messages": [
            {
                "role": "<|User|>",
                "content": instruction,
                "images": [sample["image"]],
            },
            {
                "role": "<|Assistant|>",
                "content": sample["text"],
            },
        ]
    }

converted_dataset = [convert_to_conversation(x) for x in dataset]
converted_dataset[0]
# Out:
# {'messages': [{'role': '<|User|>',
#    'content': '\nFree OCR. ',
#    'images': [<PIL.PngImagePlugin.PngImageFile image mode=RGB size=2048x112>]},
#   {'role': '<|Assistant|>',
#    'content': 'Chuyện những người mang số 115. Sáng nay ngồi quán cà phê cóc, ông bạn già của tôi tâm sự :'}]}

# %%
import torch
import math
from dataclasses import dataclass
from typing import Dict, List, Any, Tuple
from PIL import Image, ImageOps
from torch.nn.utils.rnn import pad_sequence
import io

from deepseek_ocr.modeling_deepseekocr import (
    format_messages,
    text_encode,
    BasicImageTransform,
    dynamic_preprocess,
)

@dataclass
class DeepSeekOCRDataCollator:
    """
    Args:
        tokenizer: Tokenizer
        model: Model
        image_size: Size for image patches (default: 640)
        base_size: Size for global view (default: 1024)
        crop_mode: Whether to use dynamic cropping for large images
        train_on_responses_only: If True, only train on assistant responses (mask user prompts)
    """
    tokenizer: Any
    model: Any
    image_size: int = 640
    base_size: int = 1024
    crop_mode: bool = True
    image_token_id: int = 128815
    train_on_responses_only: bool = True

    def __init__(
        self,
        tokenizer,
        model,
        image_size: int = 640,
        base_size: int = 1024,
        crop_mode: bool = True,
        train_on_responses_only: bool = True,
    ):
        self.tokenizer = tokenizer
        self.model = model
        self.image_size = image_size
        self.base_size = base_size
        self.crop_mode = crop_mode
        self.image_token_id = 128815
        self.dtype = model.dtype  # Get dtype from model
        self.train_on_responses_only = train_on_responses_only

        self.image_transform = BasicImageTransform(
            mean=(0.5, 0.5, 0.5),
            std=(0.5, 0.5, 0.5),
            normalize=True
        )
        self.patch_size = 16
        self.downsample_ratio = 4

        # Get BOS token ID from tokenizer
        if hasattr(tokenizer, 'bos_token_id') and tokenizer.bos_token_id is not None:
            self.bos_id = tokenizer.bos_token_id
        else:
            self.bos_id = 0
            print(f"Warning: tokenizer has no bos_token_id, using default: {self.bos_id}")

    def deserialize_image(self, image_data) -> Image.Image:
        """Convert image data (bytes dict or PIL Image) to PIL Image in RGB mode"""
        if isinstance(image_data, Image.Image):
            return image_data.convert("RGB")
        elif isinstance(image_data, dict) and 'bytes' in image_data:
            image_bytes = image_data['bytes']
            image = Image.open(io.BytesIO(image_bytes))
            return image.convert("RGB")
        else:
            raise ValueError(f"Unsupported image format: {type(image_data)}")

    def calculate_image_token_count(self, image: Image.Image, crop_ratio: Tuple[int, int]) -> int:
        """Calculate the number of tokens this image will generate"""
        num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
        num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

        width_crop_num, height_crop_num = crop_ratio

        if self.crop_mode:
            img_tokens = num_queries_base * num_queries_base + 1
            if width_crop_num > 1 or height_crop_num > 1:
                img_tokens += (num_queries * width_crop_num + 1) * (num_queries * height_crop_num)
        else:
            img_tokens = num_queries * num_queries + 1

        return img_tokens

    def process_image(self, image: Image.Image) -> Tuple[List, List, List, List, Tuple[int, int]]:
        """
        Process a single image based on crop_mode and size thresholds

        Returns:
            Tuple of (images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio)
        """
        images_list = []
        images_crop_list = []
        images_spatial_crop = []

        if self.crop_mode:
            # Determine crop ratio based on image size
            if image.size[0] <= 640 and image.size[1] <= 640:
                crop_ratio = (1, 1)
                images_crop_raw = []
            else:
                images_crop_raw, crop_ratio = dynamic_preprocess(
                    image, min_num=2, max_num=9,
                    image_size=self.image_size, use_thumbnail=False
                )

            # Process global view with padding
            global_view = ImageOps.pad(
                image, (self.base_size, self.base_size),
                color=tuple(int(x * 255) for x in self.image_transform.mean)
            )
            images_list.append(self.image_transform(global_view).to(self.dtype))

            width_crop_num, height_crop_num = crop_ratio
            images_spatial_crop.append([width_crop_num, height_crop_num])

            # Process local views (crops) if applicable
            if width_crop_num > 1 or height_crop_num > 1:
                for crop_img in images_crop_raw:
                    images_crop_list.append(
                        self.image_transform(crop_img).to(self.dtype)
                    )

            # Calculate image tokens
            num_queries = math.ceil((self.image_size // self.patch_size) / self.downsample_ratio)
            num_queries_base = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)

            tokenized_image = ([self.image_token_id] * num_queries_base + [self.image_token_id]) * num_queries_base
            tokenized_image += [self.image_token_id]

            if width_crop_num > 1 or height_crop_num > 1:
                tokenized_image += ([self.image_token_id] * (num_queries * width_crop_num) + [self.image_token_id]) * (
                    num_queries * height_crop_num)

        else:  # crop_mode = False
            crop_ratio = (1, 1)
            images_spatial_crop.append([1, 1])

            # For smaller base sizes, resize; for larger, pad
            if self.base_size <= 640:
                resized_image = image.resize((self.base_size, self.base_size), Image.LANCZOS)
                images_list.append(self.image_transform(resized_image).to(self.dtype))
            else:
                global_view = ImageOps.pad(
                    image, (self.base_size, self.base_size),
                    color=tuple(int(x * 255) for x in self.image_transform.mean)
                )
                images_list.append(self.image_transform(global_view).to(self.dtype))

            num_queries = math.ceil((self.base_size // self.patch_size) / self.downsample_ratio)
            tokenized_image = ([self.image_token_id] * num_queries + [self.image_token_id]) * num_queries
            tokenized_image += [self.image_token_id]

        return images_list, images_crop_list, images_spatial_crop, tokenized_image, crop_ratio

    def process_single_sample(self, messages: List[Dict]) -> Dict[str, Any]:
            """
            Process a single conversation into model inputs.
            """

            # --- 1. Setup ---
            images = []
            for message in messages:
                if "images" in message and message["images"]:
                    for img_data in message["images"]:
                        if img_data is not None:
                            pil_image = self.deserialize_image(img_data)
                            images.append(pil_image)

            if not images:
                raise ValueError("No images found in sample. Please ensure all samples contain images.")

            tokenized_str = []
            images_seq_mask = []
            images_list, images_crop_list, images_spatial_crop = [], [], []

            prompt_token_count = -1 # Index to start training
            assistant_started = False
            image_idx = 0

            # Add BOS token at the very beginning
            tokenized_str.append(self.bos_id)
            images_seq_mask.append(False)

            for message in messages:
                role = message["role"]
                content = message["content"]

                # Check if this is the assistant's turn
                if role == "<|Assistant|>":
                    if not assistant_started:
                        # This is the split point. All tokens added *so far*
                        # are part of the prompt.
                        prompt_token_count = len(tokenized_str)
                        assistant_started = True

                    # Append the EOS token string to the *end* of assistant content
                    content = f"{content.strip()} {self.tokenizer.eos_token}"

                # Split this message's content by the image token
                text_splits = content.split('')

                for i, text_sep in enumerate(text_splits):
                    # Tokenize the text part
                    tokenized_sep = text_encode(self.tokenizer, text_sep, bos=False, eos=False)
                    tokenized_str.extend(tokenized_sep)
                    images_seq_mask.extend([False] * len(tokenized_sep))

                    # If this text is followed by an  tag
                    if i < len(text_splits) - 1:
                        if image_idx >= len(images):
                            raise ValueError(
                                f"Data mismatch: Found '' token but no corresponding image."
                            )

                        # Process the image
                        image = images[image_idx]
                        img_list, crop_list, spatial_crop, tok_img, _ = self.process_image(image)

                        images_list.extend(img_list)
                        images_crop_list.extend(crop_list)
                        images_spatial_crop.extend(spatial_crop)

                        # Add image placeholder tokens
                        tokenized_str.extend(tok_img)
                        images_seq_mask.extend([True] * len(tok_img))

                        image_idx += 1 # Move to the next image

            # --- 3. Validation and Final Prep ---
            if image_idx != len(images):
                raise ValueError(
                    f"Data mismatch: Found {len(images)} images but only {image_idx} '' tokens were used."
                )

            # If we never found an assistant message, we're in a weird state
            # (e.g., user-only prompt). We mask everything.
            if not assistant_started:
                print("Warning: No assistant message found in sample. Masking all tokens.")
                prompt_token_count = len(tokenized_str)

            # Prepare image tensors
            images_ori = torch.stack(images_list, dim=0)
            images_spatial_crop_tensor = torch.tensor(images_spatial_crop, dtype=torch.long)

            if images_crop_list:
                images_crop = torch.stack(images_crop_list, dim=0)
            else:
                images_crop = torch.zeros((1, 3, self.base_size, self.base_size), dtype=self.dtype)

            return {
                "input_ids": torch.tensor(tokenized_str, dtype=torch.long),
                "images_seq_mask": torch.tensor(images_seq_mask, dtype=torch.bool),
                "images_ori": images_ori,
                "images_crop": images_crop,
                "images_spatial_crop": images_spatial_crop_tensor,
                "prompt_token_count": prompt_token_count, # This is now accurate
            }

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, torch.Tensor]:
        """Collate batch of samples"""
        batch_data = []

        # Process each sample
        for feature in features:
            try:
                processed = self.process_single_sample(feature['messages'])
                batch_data.append(processed)
            except Exception as e:
                print(f"Error processing sample: {e}")
                continue

        if not batch_data:
            raise ValueError("No valid samples in batch")

        # Extract lists
        input_ids_list = [item['input_ids'] for item in batch_data]
        images_seq_mask_list = [item['images_seq_mask'] for item in batch_data]
        prompt_token_counts = [item['prompt_token_count'] for item in batch_data]

        # Pad sequences
        input_ids = pad_sequence(input_ids_list, batch_first=True, padding_value=self.tokenizer.pad_token_id)
        images_seq_mask = pad_sequence(images_seq_mask_list, batch_first=True, padding_value=False)

        # Create labels
        labels = input_ids.clone()

        # Mask padding tokens
        labels[labels == self.tokenizer.pad_token_id] = -100

        # Mask image tokens (model shouldn't predict these)
        labels[images_seq_mask] = -100

        # Mask user prompt tokens when train_on_responses_only=True (only train on assistant responses)
        if self.train_on_responses_only:
            for idx, prompt_count in enumerate(prompt_token_counts):
                if prompt_count > 0:
                    labels[idx, :prompt_count] = -100

        # Create attention mask
        attention_mask = (input_ids != self.tokenizer.pad_token_id).long()

        # Prepare images batch (list of tuples)
        images_batch = []
        for item in batch_data:
            images_batch.append((item['images_crop'], item['images_ori']))

        # Stack spatial crop info
        images_spatial_crop = torch.cat([item['images_spatial_crop'] for item in batch_data], dim=0)

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
            "images": images_batch,
            "images_seq_mask": images_seq_mask,
            "images_spatial_crop": images_spatial_crop,
        }

# %%
from transformers import Trainer, TrainingArguments
from unsloth import is_bf16_supported

FastVisionModel.for_training(model)

data_collator = DeepSeekOCRDataCollator(
    tokenizer=tokenizer,
    model=model,
    image_size=640,
    base_size=1024,
    crop_mode=True,
    train_on_responses_only=True,
)

trainer = Trainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=converted_dataset,
    data_collator=data_collator,
    args=TrainingArguments(
        per_device_train_batch_size=1,
        gradient_accumulation_steps=8,
        warmup_steps=5,
        max_steps=60,
        learning_rate=2e-4,
        logging_steps=1,
        optim="adamw_8bit",
        weight_decay=0.001,
        lr_scheduler_type="linear",
        fp16=not is_bf16_supported(),
        bf16=is_bf16_supported(),
        output_dir="outputs",
        remove_unused_columns=False,
        report_to="none",
    ),
)
# Out:
# /tmp/ipykernel_24/2278906277.py:15: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer._unsloth___init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 8 x 1) = 16
#  "-____-"     Trainable parameters = 77,509,632 of 3,413,615,872 (2.27% trained)
# Unsloth: Not an error, but DeepseekOCRForCausalLM does not accept `num_items_in_batch`.
# Using gradient accumulation will be very slightly less accurate.
# Read more on gradient accumulation issues here: https://unsloth.ai/blog/gradient
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# Unsloth: Will smartly offload gradients to save VRAM!
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 46:12, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.957800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.862600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.819000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.027300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.269100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.334400</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.237700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.855100</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.346500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.934400</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.080000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.944400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.113200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.979900</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.885500</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.868600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.078000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.872800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.837700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.038600</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.773400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.776600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.959800</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.912500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.969700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.002400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.747100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.881800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.880100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.678100</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.834800</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.785900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.720800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.921100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.665700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.886800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.843300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.817400</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.772300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.820500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.637100</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.833800</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.829800</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.248600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.735900</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.724600</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.733100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.797200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.740300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.713300</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.516300</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.842400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.774800</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.582900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.560700</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.706300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.814400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.756300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.689000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.726500</td>
#     </tr>
#   </tbody>
# </table><p>
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# ...
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([3, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([6, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([4, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([7, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([5, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([8, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# =====================
# BASE:  torch.Size([1, 256, 1280])
# PATCHES:  torch.Size([9, 100, 1280])
# =====================
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# TrainOutput(global_step=60, training_loss=0.9326053808132807, metrics={'train_runtime': 2832.9053, 'train_samples_per_second': 0.339, 'train_steps_per_second': 0.021, 'total_flos': 2.292752420176896e+16, 'train_loss': 0.9326053808132807, 'epoch': 0.96})

# %%
model.save_pretrained("deepseek_ocr_vietnamese_lora")
tokenizer.save_pretrained("deepseek_ocr_vietnamese_lora")
# Out:
# You are using a model of type deepseek_vl_v2 to instantiate a model of type DeepseekOCR. This is not supported for all configurations of models and can yield errors.
# ('deepseek_ocr_vietnamese_lora/tokenizer_config.json',
#  'deepseek_ocr_vietnamese_lora/special_tokens_map.json',
#  'deepseek_ocr_vietnamese_lora/tokenizer.json')

# %%
from jiwer import cer
import os
import io
from contextlib import redirect_stdout

# 1. Thiết lập
output_dir = "/kaggle/working/eval_results"
os.makedirs(output_dir, exist_ok=True)
test_samples = data[1000:1100]

from unsloth import FastVisionModel
FastVisionModel.for_inference(model)

predictions = []
ground_truths = []

print(f"--- Đang chạy đánh giá trên {len(test_samples)} mẫu ---")

for i, item in enumerate(test_samples):
    img = item["image"]
    label = item["text"]
    
    temp_img_path = f"/kaggle/working/eval_{i}.jpg"
    img.save(temp_img_path)
    
    # Dùng kỹ thuật capture stdout để lấy văn bản mô hình in ra
    f = io.StringIO()
    with redirect_stdout(f):
        model.infer(
            tokenizer, 
            image_file=temp_img_path, 
            prompt="\nFree OCR. ",
            output_path=output_dir,
            base_size=1024, image_size=640, crop_mode=True,
            save_results=False
        )
    
    raw_output = f.getvalue().strip()
    
    lines = [l for l in raw_output.split('\n') if "torch.Size" not in l and "=" not in l and l.strip()]
    res_text = lines[-1] if lines else ""
    
    predictions.append(res_text)
    ground_truths.append(label)
    
    print(f"Mẫu {i+1}:")
    print(f"  > Thực tế: {label}")
    print(f"  > Dự đoán: {res_text}")
    
    if os.path.exists(temp_img_path):
        os.remove(temp_img_path)

# 2. Tính toán CER thực tế
if predictions:
    final_cer = cer(ground_truths, predictions)
    print("\n" + "="*30)
    print(f"KẾT QUẢ CUỐI CÙNG")
    print(f"Character Error Rate (CER): {final_cer * 100:.2f}%")
    print("="*30)
# Out:
# --- Đang chạy đánh giá trên 100 mẫu ---
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Mẫu 1:
#   > Thực tế: và xa bờ, hợp thành phòng tuyến bảo vệ, kiểm soát và làm chủ vùng biển.
#   > Dự đoán: với xa bờ, hấp thành phẳng được bảo vệ, kiểm toán của làm chủ sông biển.
# Mẫu 2:
#   > Thực tế: Có vị trí chiến lược quan trọng : nối liền Thái Bình Dương với Ấn Độ Dương,
#   > Dự đoán: Có sự việc chiến lược quan trọng, nổi tiếng Việt, Đinh Dương vẫn, Anh Đỗ Dương,
# Mẫu 3:
#   > Thực tế: châu Á với châu Âu, châu Úc với Trung Đông. Giao lưu quốc tế thuận
#   > Dự đoán: nhân A với chính An, chính Ôi nói rằng Đồng Giáo liệu quốc tế thương
# Mẫu 4:
#   > Thực tế: lợi, phát triển ngành biển.
#   > Dự đoán: Hồ, phát hiện ngành bên.
# Mẫu 5:
#   > Thực tế: Có khí hậu biển là vùng nhiệt đới tạo điều kiện cho sinh vật biển phát triển,
#   > Dự đoán: Có biểu hiện là rừng nhiệt độ, tạo điều kiện cho rình sạch biển phát triển,
# Mẫu 6:
#   > Thực tế: tồn tại tốt.
#   > Dự đoán: công.
# Mẫu 7:
#   > Thực tế: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
#   > Dự đoán: Cơ tài quyền trình xét xử khoáng sản phòng phí, xã đang quy định.
# Mẫu 8:
#   > Thực tế: Vùng biển và hải đảo nước ta có vị trí chiến lược hết sức to lớn, có ảnh
#   > Dự đoán: Vùng biển sâu hải đã nước ta có sự lịch lộc hết sự bồi tắm, có ánh
# Mẫu 9:
#   > Thực tế: hưởng trực tiếp đến sự nghiệp bảo vệ nền độc lập dân tộc và xây dựng
#   > Dự đoán: thông thực tiếp dẫn ra nghiệp bảo vệ nơi đức lập dân đô, vụ xây dựng
# Mẫu 10:
#   > Thực tế: chủ nghĩa xã hội, có liên quan trực tiếp đến sự phồn vinh của đất nước,
#   > Dự đoán: đầu nghĩa xa hội, có liên quan khác tiếp đón ra phía tỉnh của đất nước,
# Mẫu 11:
#   > Thực tế: đến văn minh và hạnh phúc của nhân dân.
#   > Dự đoán: đến sân mình và hành phúc của nhân dân.
# Mẫu 12:
#   > Thực tế: KHÁI QUÁT VỀ BIỂN ĐẢO VIỆT NAM
#   > Dự đoán: Khi Quát về biển đã vết năm
# Mẫu 13:
#   > Thực tế: Nước ta giáp với biển Đông ở hai phía Đông và Nam. Vùng biển Việt Nam là một phần biển
#   > Dự đoán: với tư vấn với biển đông ở hạ phía Đông và Nam. Vùng biển Việt Nam là một phần biển
# Mẫu 14:
#   > Thực tế: Đông.
#   > Dự đoán: của
# Mẫu 15:
#   > Thực tế: Bờ biển dài 3.260 km, từ Quảng Ninh đến Kiên Giang. Như vậy cứ 100 km2 thì có 1 km bờ biển
#   > Dự đoán: Bị biến đổi 3.260 ha, tại Quảng Minh đến khu Kiến Giang. Như vậy cũng đã trở về làm bị biến
# Mẫu 16:
#   > Thực tế: (trung bình của thế giới là 600 km2 đất liền / 1 km bờ biển).
#   > Dự đoán: ( Trong bình của tôi gọi là 600 km đi lại dần / 1 km bị kiện ).
# Mẫu 17:
#   > Thực tế: Biển có vùng nội thủy, lãnh hải, vùng đặc quyền kinh tế và thềm lục địa với diện tích trên 1
#   > Dự đoán: Biển có vùng nội thủy, lãnh đạo, vùng đặc nguyên lãnh tịch vụ thẩm đạo địa với biển khác trên 1
# Mẫu 18:
#   > Thực tế: triệu km2 (gấp 3 diện tích đất liền : 1 triệu km2 / 330.000 km2).
#   > Dự đoán: triệu lỗ (giá trị 3 triệu bất kỳ) là 1 triệu lỗ / 330.000 lần).
# Mẫu 19:
#   > Thực tế: Trong đó có 2 quần đảo Hoàng Sa, Trường Sa và 2.577 đảo lớn, nhỏ, gần và xa bờ, hợp
#   > Dự đoán: Trong đó có 2 quần thể trường ta, Trường ta là 2 cấp độ, giữa hai cấp, giữa hai cấp, đáp
# Mẫu 20:
#   > Thực tế: thành phòng tuyến bảo vệ, kiểm soát và làm chủ vùng biển.
#   > Dự đoán: thành phủ trực tiếp vì, khi mơ sở và khi chỉ vùng biển.
# Mẫu 21:
#   > Thực tế: Có vị trí chiến lược quan trọng : nối liền Thái Bình Dương với Ấn Độ Dương, châu Á với châu Âu,
#   > Dự đoán: Có vị trí chính được giao trong công ty, nội biểu Thái Bình Đông và Ấn Độ trong đầu tư của nó,
# Mẫu 22:
#   > Thực tế: châu Úc với Trung Đông. Giao lưu quốc tế thuận lợi, phát triển ngành biển.
#   > Dự đoán: chắc lúc với Trung Đông. Giao liên giải tài sản phải trở thành ngành kiến.
# Mẫu 23:
#   > Thực tế: Có khí hậu biển là vùng nhiệt đới tạo điều kiện cho sinh vật biển phát triển và tồn tại tốt.
#   > Dự đoán: Có thể hòa biển là vùng nhiệt đới ở địa biển của sông biển phát triển và tín hiệu.
# Mẫu 24:
#   > Thực tế: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
#   > Dự đoán: Có tài nguyên sách và tài chính sách pháp phủ, tài chính, rộng biển.
# Mẫu 25:
#   > Thực tế: Vùng biển và hải đảo nước ta có vị trí chiến lược hết sức to lớn, có ảnh hưởng trực tiếp đến sự
#   > Dự đoán: Vùng biển và hải biển nước ta có " chân biển biển " và " chân biển " có vùng biển trực tiếp với sông.
# Mẫu 26:
#   > Thực tế: nghiệp bảo vệ nền độc lập dân tộc và xây dựng chủ nghĩa xã hội, có liên quan trực tiếp đến
#   > Dự đoán: nghiệp bảo vệ nền địa phận địa vực xây dựng và phát triển, có hiện quan trọng trên biển
# Mẫu 27:
#   > Thực tế: sự phồn vinh của đất nước, đến văn minh và hạnh phúc của nhân dân.
#   > Dự đoán: số phận vốn của đối nước, đối vốn vốn mới và đối phí của nhân dân.
# Mẫu 28:
#   > Thực tế: Hội nghị Thành ủy TP.HCM lần 16 BCH Đảng bộ TP khóa VII : Kinh
#   > Dự đoán: Hỏi nghỉ Thành ủy TP.HCM lần 16 BCH Đảng bộ TP khóa VII: Kinh
# Mẫu 29:
#   > Thực tế: tế sụt giảm, nguyên nhân từ đâu? Sáng nay, 31 - 3, Hội nghị Thành ủy TP.
#   > Dự đoán: Hệ rút giảm, nguyên nhân từ đâu? Sáng nay, 31 - 3, Hội nghị Thanh ủy TP.
# Mẫu 30:
#   > Thực tế: HCM mở rộng tiếp tục làm rõ nguyên nhân vì sao tình hình kinh tế TP quý
#   > Dự đoán: #HCM mở rộng tập túc hơn rõ nguyên nhân vì sao tình hình kinh tế TP.HCM 1 quý
# Mẫu 31:
#   > Thực tế: 1 - 2004 giảm sút để từ đó đưa ra được những giải pháp khắc phục trong
#   > Dự đoán: 1 - 2014 giám sát để từ đó đưa ra được những giải pháp thực trạng
# Mẫu 32:
#   > Thực tế: quý 2. Trước đó, chiều 30 - 3, trong phần thảo luận nhiều ý kiến đã
#   > Dự đoán: gy 2. Trước đó, chiều 30 - 3, trong phần thảo luận nhiều kiến đã
# Mẫu 33:
#   > Thực tế: làm sáng tỏ thêm nguyên nhân gây ra sự trì trệ trong phát triển kinh
#   > Dự đoán: Đám sáng từ thăm nguyên nhân gây ra từ từ từ trong phát triển kinh
# Mẫu 34:
#   > Thực tế: tế...
#   > Dự đoán: tác.
# Mẫu 35:
#   > Thực tế: Phân cấp thực hiện cổ phần hóa " Tốc độ cổ phần hóa không chậm - Phó Chủ
#   > Dự đoán: Phan cấp thực hiện có phản hóa " Tôi đã có phản hóa không chậm - Thủ Chủ "
# Mẫu 36:
#   > Thực tế: tịch Mai Quốc Bình dẫn chứng - có 109 doanh nghiệp (DN) cổ phần hóa,
#   > Dự đoán: tích Mai Quốc Bình dân chúng - có 109 doanh nghiệp (DN) có phần hóa,
# Mẫu 37:
#   > Thực tế: năm 2003 mình làm được 37. Hai năm nữa là dứt điểm. Cái khó nằm
#   > Dự đoán: nam 2003 mỗi năm được 37. Hai năm nữa là đất đệm, Cái thổ năm
# Mẫu 38:
#   > Thực tế: ở khâu quyết toán tài chính DN và quyết toán thuế. Sở Tài chính làm
#   > Dự đoán: ở thành quyết toán tài chính DN và quyết toán thuế. Sở Tài chính làm
# Mẫu 39:
#   > Thực tế: không nổi. Tôi nghĩ giải quyết được hết. Không ai muốn chậm, nhưng
#   > Dự đoán: không nổi. Từ nghị giải quyết được hết. Không ai muốn chạm, nhưng
# Mẫu 40:
#   > Thực tế: cả bộ máy từ khâu này đến khâu kia lên đến TP đều chậm ". Ông Bình
#   > Dự đoán: cá họ mấy tù khâu nảy dần khâu kia đến TP đâu chạm". Thầy Bình
# Mẫu 41:
#   > Thực tế: cho biết sắp tới sẽ đề nghị trung ương phân cấp cho TP, TP phân cấp
#   > Dự đoán: cho biết sắp tới sẽ để nghị tương ứng phản cấp cho TP, TP phản cấp
# Mẫu 42:
#   > Thực tế: cho tổng công ty để đẩy nhanh hơn tốc độ cổ phần hóa.
#   > Dự đoán: Cho tổng cộng tùy đều được nhận hơn tất cả số phát hóa.
# Mẫu 43:
#   > Thực tế: " Lạ là khi tôi đề nghị phân cấp, mấy anh tổng công ty nghe phân cấp là...
#   > Dự đoán: " Sa là khi tôi đi nghỉ phản cấp, mấy anh công cộng tụ nghe phản cấp là...
# Mẫu 44:
#   > Thực tế: chạy " - ông Bình nói. Bí thư Thành ủy Nguyễn Minh Triết : " Anh là Phó
#   > Dự đoán: Chau " - ông bình nói. Bí thư Chánh ủy Nguyễn Minh Triết: " Anh là phó "
# Mẫu 45:
#   > Thực tế: Chủ tịch mà nói thế là không được! ". Phó Chủ tịch Mai Quốc Bình :
#   > Dự đoán: Chủ tịch mà nói trên là không được! ". Phó Chủ tịch Mai Quốc Bình
# Mẫu 46:
#   > Thực tế: " Nói thế cũng là tự phê. Nhưng một mình tôi gỡ không được. Việc này
#   > Dự đoán: " Nói thế cũng là từ phê. Những mặt mình trở về thông điệp, Việt này
# Mẫu 47:
#   > Thực tế: liên quan nhiều khâu, qua khâu khác là của người khác, không
#   > Dự đoán: Liên quan đến hiện thực, qua khâu khác là cơ sở người khác, không
# Mẫu 48:
#   > Thực tế: sờ mó tới được ". Hạ tầng cơ sở là yếu tố quan trọng hấp
#   > Dự đoán: Sợ mở thở được ". Họ tăng cơ sở là yêu tôi quan trọng hấp
# Mẫu 49:
#   > Thực tế: dẫn nhà đầu tư.
#   > Dự đoán: dân nhà đã tu.
# Mẫu 50:
#   > Thực tế: Ông Hà Văn Dũng, Giám đốc Sở Giao thông công chánh, đề nghị đưa vào
#   > Dự đoán: Ông Vă Văn Dũng, Giám đốc Sở Giao thông công chính, đã nghỉ đưa vào
# Mẫu 51:
#   > Thực tế: chương trình công tác quý 2 một số việc liên quan đến ngành giao
#   > Dự đoán: chuyển kinh công tài quý 2 mặt số việc liên quan đến ngân giao
# Mẫu 52:
#   > Thực tế: thông : mở một cảng ở Phú Hữu, quận 7 để giảm 25% lượng xe tải vào
#   > Dự đoán: thông : mở mặt cảng ở Phú Hữu, quận 7 để giảm 25% lượng xe tại và
# Mẫu 53:
#   > Thực tế: TP. Ông thông tin : " Nhà nước chỉ cần hỗ trợ 30 tỉ đồng tiền mặt
#   > Dự đoán: TP. Ông thông tin : " Nhà nước chỉ cần hồ sơ, đã đăng thân mật
# Mẫu 54:
#   > Thực tế: bằng, còn các DN vận tải biển đồng ý hợp tác đầu tư toàn bộ
#   > Dự đoán: bảng, con cá ON vốn tài biên đáng ý Rạp tới đâu từ đâu bị
# Mẫu 55:
#   > Thực tế: cầu cảng. Tôi nói thiệt, DN sợ " lót đường " nên rất muốn vô thẳng
#   > Dự đoán: câu cảng. Tôi nói thật, ON nói " lột tương " nên rất muốn và thắng
# Mẫu 56:
#   > Thực tế: Phú Hữu ".
#   > Dự đoán: Phú Túi ".
# Mẫu 57:
#   > Thực tế: Thời gian xây dựng cảng chỉ mất một năm. Ông Dũng cũng cho biết sẽ cố
#   > Dự đoán: Thời gian xây dựng cảng chỉ mất một năm. Ông Dũng cũng cho biết nó có
# Mẫu 58:
#   > Thực tế: gắng khởi công sớm đường Trường Chinh do công tác đền bù giải tỏa
#   > Dự đoán: gồng khởi công nơi đường Trường Chính do công tác đến bị giải trí
# Mẫu 59:
#   > Thực tế: tương đối khả quan. Ông Dũng đưa một tin đáng mừng : Vài ngày
#   > Dự đoán: trường đời khá quan. Ông Dũng đã mất tin đáng mừng: Và ngày
# Mẫu 60:
#   > Thực tế: nữa TP sẽ được cung cấp một lượng nước sạch bằng nửa lượng
#   > Dự đoán: nước TP sẽ được cung cấp mặt bằng nước sạch bằng nước liệu gì?
# Mẫu 61:
#   > Thực tế: nước hiện có, và đề nghị TP triển khai tiếp dự án cung cấp
#   > Dự đoán: nuôi chèo có, và đã nghỉ TP triển khai tiếp dự án cung cấp
# Mẫu 62:
#   > Thực tế: nước sạch khác để TP sẽ có thêm 300.000 m3
#   > Dự đoán: mặc dù khá rất từ TP sẽ có thêm 300.000 m3
# Mẫu 63:
#   > Thực tế: KHÁI QUÁT VỀ BIỂN ĐẢO VIỆT NAM
#   > Dự đoán: KHÁI QUÁT VỀ BIỆN ĐẢO VIỆT NAM
# Mẫu 64:
#   > Thực tế: Nước ta giáp với biển Đông ở hai phía Đông và Nam. Vùng biển Việt Nam là một
#   > Dự đoán: Nước ta gặp với bốn Đông ở hai phía Đông và Nam. Vùng biển Việt Nam là một
# Mẫu 65:
#   > Thực tế: phần biển Đông.
#   > Dự đoán: Phân biệt bằng.
# Mẫu 66:
#   > Thực tế: Bờ biển dài 3.260 km, từ Quảng Ninh đến Kiên Giang. Như vậy cứ 100 km2 thì
#   > Dự đoán: bộ biển dự 3.500 km, thì Quảng Minh đến kiên Giang. Như vậy cứ 100 km thì
# Mẫu 67:
#   > Thực tế: có 1 km bờ biển (trung bình của thế giới là 600 km2 đất liền / 1 km bờ biển).
#   > Dự đoán: có 1 km bờ biển (trung bình của thế giới là 600 km2 đất liền / 1 km bờ biển).
# Mẫu 68:
#   > Thực tế: Biển có vùng nội thủy, lãnh hải, vùng đặc quyền kinh tế và thềm lục địa với
#   > Dự đoán: bên có vùng nơi thủy, lạnh hơi, vùng đặc quyền kinh tế và thềm lục địa với
# Mẫu 69:
#   > Thực tế: diện tích trên 1 triệu km2 (gấp 3 diện tích đất liền : 1 triệu km2 / 330.000
#   > Dự đoán: điểm tích tiền 1 triệu bạc (gấp 3 diện tích đất liền : 1 triệu bạc / 330.000
# Mẫu 70:
#   > Thực tế: km2
#   > Dự đoán: bấm 2.
# Mẫu 71:
#   > Thực tế: Trong đó có 2 quần đảo Hoàng Sa, Trường Sa và 2.577 đảo lớn, nhỏ, gần và
#   > Dự đoán: Trong đó có 2 quyền đạo thương Sa, Trương Sa và 2.577 đạo lớn, nhỏ, giản và
# Mẫu 72:
#   > Thực tế: xa bờ, hợp thành phòng tuyến bảo vệ, kiểm soát và làm chủ vùng biển.
#   > Dự đoán: xa bộ, hộp thành phong tuyến hóa vé, kiểm soát và làm chủ vùng biển.
# Mẫu 73:
#   > Thực tế: Có vị trí chiến lược quan trọng : nối liền Thái Bình Dương với Ấn Độ Dương,
#   > Dự đoán: Có vì từ chính được quan tâm, nói liên thủ bình Đảng với tư độ Đảng,
# Mẫu 74:
#   > Thực tế: châu Á với châu Âu, châu Úc với Trung Đông. Giao lưu quốc tế thuận lợi,
#   > Dự đoán: châu ở với chân thu, chân lúc với Trương Đông. Giáo dục quốc tế thuộc lại,
# Mẫu 75:
#   > Thực tế: phát triển ngành biển.
#   > Dự đoán: Phát triển ngành bưu.
# Mẫu 76:
#   > Thực tế: Có khí hậu biển là vùng nhiệt đới tạo điều kiện cho sinh vật biển phát
#   > Dự đoán: Có khi hậu biển là vùng nhiệt đội tạo điều kiện cho kinh vật biển phát
# Mẫu 77:
#   > Thực tế: triển, tồn tại tốt.
#   > Dự đoán: 越南，
# Mẫu 78:
#   > Thực tế: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
#   > Dự đoán: Có đại nguyên nhân vất vả khoảng 100 phòng phú, đã dương, quy hiện.
# Mẫu 79:
#   > Thực tế: Vùng biển và hải đảo nước ta có vị trí chiến lược hết sức to lớn, có ảnh
#   > Dự đoán: Vùng biển và hải đảo nước ta có vị trí chính biển hết sức ta lớn, có ảnh
# Mẫu 80:
#   > Thực tế: hưởng trực tiếp đến sự nghiệp bảo vệ nền độc lập dân tộc và xây dựng chủ nghĩa
#   > Dự đoán: thương thực tiếp dẫn sự nghiệp báo về nền độc lập dân tộc và xây dựng chủ nghĩa
# Mẫu 81:
#   > Thực tế: xã hội, có liên quan trực tiếp đến sự phồn vinh của đất nước, đến văn
#   > Dự đoán: xã hội, có liên quan thực tiếp đến sự phản vinh của đất nước, đến văn
# Mẫu 82:
#   > Thực tế: minh và hạnh phúc của toàn dân.
#   > Dự đoán: mình và thành phúc của đoàn dân.
# Mẫu 83:
#   > Thực tế: KHÁI QUÁT VỀ BIỂN ĐẢO VIỆT NAM
#   > Dự đoán: KHÁI QUÁT VỀ BIỂN ĐẠO VIỆT NAM
# Mẫu 84:
#   > Thực tế: Nước ta giáp với biển Đông ở hai phía Đông và Nam. Vùng biển Việt Nam là một phần
#   > Dự đoán: Nước ta giúp với biển Đông ở hai phía Đông và Nam. Vùng biển Việt Nam là nơi phải
# Mẫu 85:
#   > Thực tế: biển Đông.
#   > Dự đoán: bình bóng.
# Mẫu 86:
#   > Thực tế: Bờ biển dài 3.260 km, từ Quảng Ninh đến Kiên Giang. Như vậy cứ 100 km2 thì có 1 km
#   > Dự đoán: Bộ biển dài 3.260 km, tại Quảng Ninh đến Kiên Giang. Một ngày các đoàn trại 1 km
# Mẫu 87:
#   > Thực tế: bờ biển (trung bình của thế giới là 600 km2 đất liền / 1 km bờ biển).
#   > Dự đoán: bộ biển (Trung bình của thế giới là 600km2 đất liền / 1km2 bị biển).
# Mẫu 88:
#   > Thực tế: Biển có vùng nội thủy, lãnh hải, vùng đặc quyền kinh tế và thềm lục địa với diện tích
#   > Dự đoán: Bên có vùng nơi thủy, lạnh hơi, vùng đặc quyền khách và thềm lục địa với đất đất
# Mẫu 89:
#   > Thực tế: trên 1 triệu km2 (gấp 3 diện tích đất liền : 1 triệu km2 / 330.000 km2)
#   > Dự đoán: trên 1 triệu lệnh Giap 3 diện tích đất liền : 1 triệu lên 2 / 30.000 lần )
# Mẫu 90:
#   > Thực tế: Trong đó có 2 quần đảo Hoàng Sa, Trường Sa và 2.577 đảo lớn, nhỏ, gần và xa bờ,
#   > Dự đoán: Trong đó có 2 quần đảo Hoàng Sự Trường Sa và 2 5 F Tàu lớn, nhỏ, gần và xa bờ,
# Mẫu 91:
#   > Thực tế: hợp thành phòng tuyến bảo vệ, kiểm soát và làm chủ vùng biển.
#   > Dự đoán: hợp thành phòng tuyển bào rác, kiểm soát và làm chủ vùng biển.
# Mẫu 92:
#   > Thực tế: Có vị trí chiến lược quan trọng : nối liền Thái Bình Dương với Ấn Độ Dương, châu Á
#   > Dự đoán: Có vị trí chính được quan trọng : nơi liên Than Định Đông với Ấn Độ Đường châu Á
# Mẫu 93:
#   > Thực tế: với châu Âu, châu Úc với Trung Đông. Giao lưu quốc tế thuận lợi, phát triển ngành
#   > Dự đoán: Với chân An, chân lực vĩ Trung Đông. Giáo luận quốc tế huấn lựi phát triển ngành
# Mẫu 94:
#   > Thực tế: biển.
#   > Dự đoán: - có? Đã.
# Mẫu 95:
#   > Thực tế: Có khí hậu biển là vùng nhiệt đới tạo điều kiện cho sinh vật biển phát triển, tồn tại tốt.
#   > Dự đoán: Có lẽ hầu biển là vùng nhiệt đới tạo điều kiện cho sinh sối bên phải trường bên tái tết.
# Mẫu 96:
#   > Thực tế: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
#   > Dự đoán: Có tài nguyên sinh vật và khoáng sản phong phú, đa dạng, quý hiếm.
# Mẫu 97:
#   > Thực tế: Vùng biển và hải đảo nước ta có vị trí chiến lược hết sức to lớn, có ảnh hưởng trực
#   > Dự đoán: Vùng biển và hà dào nước ta có ưu tiên chiến lược kết quả tốn, có ảnh hưởng tiêu
# Mẫu 98:
#   > Thực tế: tiếp đến sự nghiệp bảo vệ nền độc lập dân tộc và xây dựng chủ nghĩa xã hội, có liên
#   > Dự đoán: hiệp đến nơi nghiệp bảo vệ nền đào lấp dân trở ra xây dựng chủ nghĩa và thời, có liên
# Mẫu 99:
#   > Thực tế: quan trực tiếp đến sự phồn vinh của đất nước, đến văn minh và hạnh phúc của
#   > Dự đoán: quan trực tiếp đến trụ phim với các đối tượng, đến văn minh và hạnh phúc của
# Mẫu 100:
#   > Thực tế: nhân dân.
#   > Dự đoán: nhân dân.
#
# ==============================
# KẾT QUẢ CUỐI CÙNG
# Character Error Rate (CER): 21.17%
# ==============================
